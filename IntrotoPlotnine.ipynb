# %%
import polars as pl
import plotnine as pn

# %%
#This code expands the default plot size:
pn.options.figure.size = (6, 4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 #This code expands the default plot size:
# ----> 2 pn.options.figure.size = (6, 4)
#
# AttributeError: module 'plotnine.options' has no attribute 'figure'
